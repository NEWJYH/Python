# %%
# if ~ eliB ~ else(옵션) 대한 실습

score = int(input("성적을 입력하세요(0~100점) : "))

# 다중 조건 중 하나만 만족하면, 그 이후의 조건은 검사하지 않는다.
if score >= 90:
    print("학점 A")
elif score >= 80 :
    print("학점 B")
elif score >= 70 :
    print("학점 C")
elif score >= 60 :
    print("학점 D")
else:
    print("학점 F")
# Out:
# 성적을 입력하세요(0~100점) : 98
# 학점 A

# %%
# 중첩(nested) if ~ else 구문 실습

appleQualty = input("사과의 상태를 입력하시오(좋음, 나쁨) : ")
if appleQualty == "좋음":
    applePrice = int(input("사과 1개당 가격을 입력하세요 : "))
    if applePrice < 1000:
        print("10개를 산다")
    else:
        print("5개를 산다")
elif appleQualty == "나쁨":
    print("사과를 사지 않는다")
else:
    print("잘못된 입력입니다.")
# Out:
# 사과의 상태를 입력하시오(좋음, 나쁨) : ㅋㅋ
# 잘못된 입력입니다.

# %%
# 사용자로부터 정수를 입력받아서 음수 또는 0, 양수 중에 어떤 값 인지
# 출력하는 프로그램을 만들어보시오.

print(" 똥같은 음,0,양 수 구분 프로그램")

input_number = int(input("정수를 입력해주세요 : "))


if input_number == 0 :
    print("입력한 숫자는 0 입니다")
elif input_number >0 :
    print("입력한 숫자는 양수 입니다.")
else :
    print("입력한 숫자는 음수 입니다.")
# Out:
# 음,0,양 수 구분기
# 정수를 입력해주세요 : -5
# 입력한 숫자는 음수 입니다.

# %%
# 주사위 눈을 랜덤으로 발생시켜서 해당하는 숫자를 출력하는 프로그램을 만들기
# randint()함수를 검색하여 사용법을 익힌 후 프로그램을 작성하시오.

# random.random()
# 0.0에서 1.0 사이의 실수를 반환

# random.uniform(a,b)
# a <=  x <= b 실수 반환

# randint(a,b)
# a <=  x <= b 정수 반환
 
# randrange(a,b) , randrange(b)
# a<= x < b ,x<b 정수 반환

import random

num = random.randint(1,6)
print("주사위 값 : ", num)
# Out:
# 주사위 값 :  6

# %%
from random import *


while True:
    num = random()
    print(num)
    num1 = randint(1,6)
    print(num1)
    num2 = randrange(1,101)
    print(num2)
    k = input("종료 키 k")
    if k == "k":
        break
# Out:
# 0.5725487181340179
# 5
# 94
# 종료 키 k3
# 0.41925130798546606
# 1
# 83
# 종료 키 k
# 0.07678930904501824
# 3
# 13
# 종료 키 k
# 0.5354624345017256
# 2
# 43
# 종료 키 k
# 0.8191641037756099
# 4
# 8
# 종료 키 k
# 0.05302223954234586
# 1
# 51
# 종료 키 k
# 0.5221728977497636
# 3
# 32
# 종료 키 k
# 0.6417168473122506
# 1
# 96
# 종료 키 k
# 0.1809511816304311
# 5
# 34
# 종료 키 k
# 0.25589570735191125
# 1
# 11
# 종료 키 k
# 0.338234789048352
# 6
# 30
# 종료 키 k
# 0.8484048382105643
# 1
# 32
# 종료 키 k
# 0.24880091254616743
# 1
# 9
# 종료 키 k
# 0.13913726943006066
# 6
# 99
# 종료 키 k
# 0.3693312178112885
# 2
# 28
# 종료 키 k
# 0.7835146018098266
# 5
# 3
# 종료 키 k
# 0.8347363975668478
# 5
# 35
# 종료 키 k
# 0.3800116929474653
# 2
# 24
# 종료 키 k
# 0.38760826172403107
# 4
# 86
# 종료 키 k
# 0.23413621653638983
# 1
# 2
# 종료 키 k
# 0.23703413692690012
# 5
# 3
# 종료 키 k
# 0.5563472198804911
# 4
# 96
# 종료 키 k
# 0.7675399029451172
# 4
# 95
# 종료 키 k
# 0.11177424099189026
# 3
# 32
# 종료 키 k
# 0.7319515068743849
# 1
# 98
# 종료 키 k
# ...
