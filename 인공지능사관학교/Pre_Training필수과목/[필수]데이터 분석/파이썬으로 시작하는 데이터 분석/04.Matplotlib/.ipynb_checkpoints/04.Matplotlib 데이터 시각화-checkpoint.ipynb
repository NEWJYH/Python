# %% [markdown]
# Matplotlib 소개
#
# Matplotlib
# 파이썬에서 데이터를 그래프나 차트로
# 시각화 할수 있는 라이브러리

# %% [markdown]
# 그래프  그려보기

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

plt.plot(x,y)

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

plt.plot(x,y)
# 상단
plt.title("First Plot")
# x축 라벨
plt.xlabel("x")
# y축 라벨
plt.ylabel("y")

plt.show()

# %%
import matplotlib.pyplot as plt
# 객체 기반 스타일로 그래프 그리기

x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]
fig, ax = plt.subplots()

ax.plot(x, y)

ax.set_title("First Plot")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# matplotlib 구조

# %%
from IPython.display import Image
Image("./matplotlib.png")

# %% [markdown]
# matplotlib 구조
# Figure 가장 큰 도화지
#    그래프를 모두 포함
#
# 위에 라인 그래프
#   잠이 이어진 그래프
#
# 아래 scatter plot 산점도
#    점이 이어지지 않은 그래프
#
# Grid + 격자모양
#   수정 만들수 있음
#
# Major tick 큰 눈금
# Minor tick 작은 눈금
#
# Legend 범례
#   어떤 그래프를 나타내는지

# %% [markdown]
# 저장하기

# %%
import matplotlib.pyplot as plt


x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

fig, ax = plt.subplots()
# fig <- 전체 도화지를 뜻함
# ax <- 그래프를 그릴 수 있는 곳

# 그래프 그리기
ax.plot(x, y)

ax.set_title("First Plot")
ax.set_xlabel("x")
ax.set_ylabel("y")

# dpi - dotperinch 1인치 제곱당 몇 도트까지 들어갈수 있는지 지정? 
# 300정도 지정 # 낮출경우 해상도 떨어짐
fig.set_dpi(300)

# 저장하기
fig.savefig("first_plot.png")

# %% [markdown]
# 여러개 그래프 그리기

# %%
import numpy as np # 넘파이
import pandas as pd # 판다스
import matplotlib.pyplot as plt # matplotlib

# 넘파이 
# np.linspace 
# 0부터 pi*4 까지 100개의 구간으로 나눔
x = np.linspace(0, np.pi*4, 100)

# subplots(2, 1)
# 인자 2,1 => 2행 1열의 그래프
fig, axes = plt.subplots(2, 1) 

# 위 그래프
axes[0].plot(x, np.sin(x))
# 아래 그래프
axes[1].plot(x, np.cos(x))

# %% [markdown]
# Matplotlib 기초
# 데이터를 시각화하기 위해 Matplotlib에 대해서 알아봅시다.
#
# Matplotlib은 막대 그래프, 산점도 등 데이터 시각화 기능을 가진 대표적인 파이썬 라이브러리입니다.
#
# 앞에서 배운 numpy, pandas에서 처리한 데이터를 한 번 그래프로 그려봅시다.
#
# 따라해보기1
#
# 두 개의 리스트 X, Y를 matplotlib로 그래프로 그려봅시다.
#
# x = [1, 2, 3, 4, 5]
# y = [1, 2, 3, 4, 5]
# fig, ax = plt.subplots()
# ax.plot(x, y)
# ax.set_title("First Plot")
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# 실습
#
# 영상을 확인해보고 그래프를 그리고 라벨을 붙이기도 해봅시다.
#
#
# 지시사항
# 오른쪽에, x와 y 리스트가 있습니다.
#
# x와 y의 값으로 그래프를 그려보도록 합니다.
#
# x와 y의 값을 변경하고 그래프를 그렸을 때의 모양도 확인해보세요.
#
# Tip!
# subplots는 1개의 figure와 1개 이상의 그래프(ax)를 생성할 수 있습니다.
#
# figure는 그래프를 그리는 도화지같은 개념입니다.
#
# 옵션을 지정함에 따라, 1개의 figure에 2개 이상의 그래프를 같이 그릴 수도 있습니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]
# 그래프를 그리는 코드 작성

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("First Plot")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# matplotlib 그래프들

# %% [markdown]
# Line plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

x = np.arange(15) # 0 ~ 14
y = x ** 2

ax.plot(
    x, y,
    linestyle=":",
    marker="*",
    color="#524FA1"
)

# %% [markdown]
# Line style

# %%
x = np.arange(10) # 0 ~ 9
fig, ax = plt.subplots()

# solid
ax.plot(x, x, linestyle="-")

# dashed
ax.plot(x, x+2, linestyle="--")

# dashdot
ax.plot(x, x+4, linestyle="-.")

# dotted
ax.plot(x, x+6, linestyle=":")

fig.set_dpi(300)

# %% [markdown]
# Color

# %%
x = np.arange(10)

fig, ax = plt.subplots()

# 문자의 축약어
# rgb, cnyk
ax.plot(x,x, color="r")

# 풀네임
ax.plot(x,x+2, color="green")

# 문자열 회색조 0검은색 1이면 투명한 색
ax.plot(x,x+4, color="0.8")

# rgb에 대한 16진수 코드
ax.plot(x,x+6, color="#524FA1")

fig.set_dpi(300)

# %% [markdown]
# Marker

# %%
x = np.arange(10)

fig, ax = plt.subplots()

# 작은 점
ax.plot(x,x, marker=".")

# 큰 원
ax.plot(x,x+2, marker="o")

# 아래 삼각형
ax.plot(x,x+4, marker="v")

# 네모
ax.plot(x,x+6, marker="s")

# 별표
ax.plot(x,x+8, marker="*")

fig.set_dpi(300)

# %% [markdown]
# 축 경계 조정하기

# %%
# 0부터 10사이의 1000개의 데이터를 뽑아서 x로 가져옴
x = np.linspace(0, 10, 1000)

fig, ax = plt.subplots()

ax.plot(x, np.sin(x))


# x축의 시작점 -2,  끝나는지점 12
ax.set_xlim(-2, 12)

# y축의 시작점 -1.5, 끝나는 지점 1.5
ax.set_ylim(-1.5, 1.5)

fig.set_dpi(300)

# %% [markdown]
# 범례

# %%
x = np.arange(10)

fig, ax = plt.subplots()

ax.plot(x,x, label="y=x")
ax.plot(x,x**2, label ="y=x^2")

ax.set_xlabel("x")
ax.set_ylabel("y")

ax.legend(
    loc="upper right", # 위치 지정 lower left center
    shadow=True, # 그림자  
    fancybox=True, # 모서리 둥글게 만드는 것 
    borderpad=2 # 범례 크기
    )

fig.set_dpi(300)

# %% [markdown]
# Line Graph
# matplotlib으로 그릴 수 있는 여러가지 그래프 중 선 그래프(Line Graph)를 직접 그려봅시다.
#
# 속성(linestyle, marker, color) 값을 변경하여 그래프를 그리는 다양한 방법에 대해서 알아봅시다.
#
# 영상을 확인해보고 그래프의 속성을 변경하여 봅시다.
#
# 자주 사용되는 옵션은 아래와 같습니다.
#
# Line Styles
#
# 기호	의미
# -	실선
# --	대시 선
# -.	대시 점 선
# :	점선
# Markers
#
# 기호	의미	기호	의미
# .	점	,	픽셀
# o	원	s	사각형
# v, <, ^, >	삼각형	1, 2, 3, 4	삼각선
# p	오각형	H, h	육각형
#
# 지시사항
# ax.plot 함수의 marker, color, linestyle 의 옵션을 변경하실 수 있습니다.
#
# Tip!
# 예시 코드에서 figure와 ax가 각각 1개인데, ax.plot 함수를 두 번 호출했죠?
#
# 이렇게 하나의 ax에 여러 번 그래프를 그리면, 그래프를 겹쳐서 그릴 수 있습니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#이미 입력되어 있는 코드의 다양한 속성값들을 변경해 봅시다.
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    marker='s',
    color='blue',
    linestyle=':'
)
ax.plot(
    x, x**2, label='y=x^2',
    marker='^',
    color='red',
    linestyle='--'
)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend(
    loc='upper center',
    shadow=False,
    fancybox=False,
    borderpad=1
)

fig.set_dpi(300)

# %% [markdown]
# Scatter

# %% [markdown]
# Scatter : 점이 이어지지 않는 그래프 (산점도)

# %%
fig, ax = plt.subplots()

x = np.arange(10)

ax.plot(
    x, x**2, "o", # 3번째 인자 "o" 일경우 스캐터 그래프
    markersize=15, # 원의 크기
    markerfacecolor="red", # 원의 안쪽 색
    markeredgecolor="black" # 원의 바깥쪽 색
)

fig.set_dpi(300)

# %% [markdown]
# Scatter

# %%
fig, ax = plt.subplots()

# 정규분포 50개
x = np.random.randn(50)
y = np.random.randn(50)

# 0부터 100사이의 50개의 값
colors = np.random.randint(0,100,50) 

# 0~50사이 랜덤한 숫자 중 하나를 뽑아 제곱한 후
# pi에 500을 곱함
sizes = 500 * np.pi * np.random.rand(50)**2

ax.scatter(x,y,         # 점의 중앙 위치
           c = colors,  # 숫자로 지정한 컬러값
           s = sizes,   # 얼마 만큼의  크기
           alpha = 0.3) # 투명도 값


fig.set_dpi(300)

# %% [markdown]
# Scatter
# Scatter 그래프에 대해서 알아봅시다.
#
# Scatter 그래프는 산점도라고도 하는데, 이를 사용하게 되면 값 사이의 관계를 파악하기 용이해지고 데이터 셋에서 이상값을 찾기도 용이합니다.
#
# 둘 이상의 측정값의 상관 관계를 파악하고 시각화 할 수 있는 훌륭한 그래프 입니다.
#
# 산점도를 직접 만들어보고 출력을 확인해보세요.
#
# x = np.random.randn(50)
# y = np.random.randn(50)
# colors = np.random.randint(0, 100, 50)
# sizes = 500 * np.pi * np.random.rand(50) ** 2
#
# ax.scatter(
#     x, y, c = colors, s = sizes
# )
#
# 지시사항
# scatter 함수를 사용하여 산점도를 만들고 코드를 살펴보세요.
#
# Tip!
# 예시 코드에서는 colors와 sizes가 무작위 값으로 설정되었지만, 실제로 데이터 분석을 지정할 때에는 데이터의 성향에 따라 색을 구분해 줄 수 있고, 데이터의 크기에 따라 점의 크기를 조절할 수 있습니다.
#
# 변수의 값 뿐만 아니라, 색깔과 크기를 적절히 조절하면 시각화를 하는 의도를 효과적으로 나타낼 수 있습니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = np.arange(10)
ax.plot(
    x, x**2, "o",
    markersize=15,
    markerfacecolor='white',
    markeredgecolor="blue"
)

# %% [markdown]
# Bar & Histogram

# %% [markdown]
# Bar plot

# %%
x = np.arange(10)
# 인자 figsize <- 도화지 사이즈 : (12, 4) <- 가로 12 세로 4
fig, ax = plt.subplots(figsize=(12, 4))
ax.bar(x, x**2)

#fig.set_dpi(300)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Bar plot

# %%
x = np.random.rand(3)
y = np.random.rand(3)
z = np.random.rand(3)

data = [x, y, z]

fig , ax = plt.subplots()

x_ax = np.arange(3)

for i in x_ax:
    ax.bar(x_ax, data[i],
          bottom=np.sum(data[:i], axis=0))

ax.set_xticks(x_ax)
ax.set_xticklabels(["A","B","C"])
# Out:
# [Text(0, 0, 'A'), Text(1, 0, 'B'), Text(2, 0, 'C')]

# %% [markdown]
# Histogram

# %%
fig, ax = plt.subplots()
# 표준 정규분포에서 1000개
data = np.random.randn(1000)
# bins = 50개로 기둥을 나눔
ax.hist(data, bins=50)
# Out:
# (array([ 1.,  0.,  0.,  1.,  1.,  1.,  3.,  3.,  3.,  9.,  7.,  7., 14.,
#         16., 23., 29., 23., 31., 46., 44., 46., 51., 35., 43., 49., 57.,
#         51., 60., 41., 57., 39., 35., 33., 20., 27., 23., 12., 20., 11.,
#          7.,  5.,  2.,  3.,  5.,  1.,  0.,  2.,  1.,  1.,  1.]),
#  array([-3.36253678, -3.22978261, -3.09702844, -2.96427427, -2.8315201 ,
#         -2.69876593, -2.56601176, -2.43325759, -2.30050343, -2.16774926,
#         -2.03499509, -1.90224092, -1.76948675, -1.63673258, -1.50397841,
#         -1.37122424, -1.23847007, -1.1057159 , -0.97296173, -0.84020756,
#         -0.7074534 , -0.57469923, -0.44194506, -0.30919089, -0.17643672,
#         -0.04368255,  0.08907162,  0.22182579,  0.35457996,  0.48733413,
#          0.6200883 ,  0.75284247,  0.88559664,  1.0183508 ,  1.15110497,
#          1.28385914,  1.41661331,  1.54936748,  1.68212165,  1.81487582,
#          1.94762999,  2.08038416,  2.21313833,  2.3458925 ,  2.47864667,
#          2.61140083,  2.744155  ,  2.87690917,  3.00966334,  3.14241751,
#          3.27517168]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# Bar & Histogram
# Bar그래프와 Histogram에 대해서 알아봅시다.
#
# 우리가 잘알고 있는 Bar그래프(막대형 차트)는 여러 값을 비교하는데 적합합니다. 여러개의 값을 입력 받고 그 값들을 한눈에 비교 할 수 있습니다.
#
# Histogram은 일정 시간 동안의 숫자 데이터 분포를 시각화 하는데 적합합니다.
#
# x와 y 데이터는 각 스포츠의 종목과, 선호하는 학생의 수를 조사한 결과입니다.
#
# x와 y 데이터로 막대 그래프를 그립니다.
#
# z 데이터는 1000개의 정규분포 난수를 담고 있습니다.
#
# z 데이터를 등급을 50개로 나눈 히스토그램으로 출력해봅니다.
#
#
# 지시사항
# 주어진 코드를 확인해보고, 막대 그래프와 히스토그램의 차이를 알아봅시다.
#
# Tip!
# fig, axes = plt.subplots(1, 2, figsize=(8, 4))
# Copy
# 이 코드는, 하나의 도화지(figure)에
# 1*2의 모양으로 그래프를 그리도록 합니다.
#
# 그래프를 2개 그리고, 가로로 배치한다는 의미입니다.
#
# axes[0]은 막대 그래프를, axes[1]은 히스토그램을 그립니다.
#
# Tip 2!
# matplotlib 의 pyplot으로 그래프를 그릴 때, 기본 폰트는 한글을 지원하지 않습니다.
#
# 한글 지원 폰트로 직접 바꾸어주면 한글을 사용하실 수 있습니다.
#
# 아래는 한글을 지원하는 나눔바른고딕 폰트로 바꾼 코드입니다.
#
# import matplotlib.font_manager as fm
# fname='./NanumBarunGothic.ttf'
# font = fm.FontProperties(fname = fname).get_name()
# plt.rcParams["font.family"] = font
# Copy
# 위 코드 덕분에, 막대 그래프에서 축구, 야구, 농구, 배드민턴, 탁구가 올바르게 출력되었습니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fname='./NanumBarunGothic.ttf'
font = fm.FontProperties(fname = fname).get_name()
plt.rcParams["font.family"] = font


x = np.array(["축구", "야구", "농구", "배드민턴", "탁구"])
y = np.array([18, 7, 12, 10, 8])

z = np.random.randn(1000)


fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Bar 그래프
axes[0].bar(x, y)
# 히스토그램
axes[1].hist(z, bins = 50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  0.,  2.,  3.,  5.,  3.,
#          7.,  7., 13.,  9., 21., 27., 21., 33., 37., 44., 44., 45., 45.,
#         56., 52., 54., 42., 47., 48., 40., 39., 35., 46., 40., 26., 19.,
#         16., 18., 11., 12.,  8.,  4.,  7.,  5.,  2.,  3.,  2.]),
#  array([-3.87193153, -3.73634379, -3.60075606, -3.46516832, -3.32958059,
#         -3.19399285, -3.05840511, -2.92281738, -2.78722964, -2.6516419 ,
#         -2.51605417, -2.38046643, -2.24487869, -2.10929096, -1.97370322,
#         -1.83811548, -1.70252775, -1.56694001, -1.43135228, -1.29576454,
#         -1.1601768 , -1.02458907, -0.88900133, -0.75341359, -0.61782586,
#         -0.48223812, -0.34665038, -0.21106265, -0.07547491,  0.06011282,
#          0.19570056,  0.3312883 ,  0.46687603,  0.60246377,  0.73805151,
#          0.87363924,  1.00922698,  1.14481472,  1.28040245,  1.41599019,
#          1.55157792,  1.68716566,  1.8227534 ,  1.95834113,  2.09392887,
#          2.22951661,  2.36510434,  2.50069208,  2.63627982,  2.77186755,
#          2.90745529]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# Matplotlib with Pandas

# %% [markdown]
# Matplotlib with Pandas
# Pandas를 이용해 csv 파일을 불러와 시각화를 진행해보도록 하겠습니다.
#
# 포켓몬에 대한 데이터가 담긴 csv 파일을 불러와서 공격 타입에 따라 그래프를 그리고 라벨을 한번 붙여보도록 합시다.
#
# 공격 능력치와 수비 능력치가 x와 y축으로 주어지고, 물 속성 포켓몬은 파란색, 불 속성 포켓몬은 빨간색으로 표현한 모습입니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("./pokemon.csv")

fire = df[
    (df['Type 1']=='Fire') | ((df['Type 2'])=="Fire")
]

water = df[
    (df['Type 1']=='Water') | ((df['Type 2'])=="Water")
]

fig, ax = plt.subplots()

ax.scatter(fire['Attack'], fire['Defense'],
    color='Red', label='Fire', marker="*", s=50)

ax.scatter(water['Attack'], water['Defense'],
    color='Blue', label="Water", s=25)

ax.set_xlabel("Attack")
ax.set_ylabel("Defense")

ax.legend(loc="upper right")
