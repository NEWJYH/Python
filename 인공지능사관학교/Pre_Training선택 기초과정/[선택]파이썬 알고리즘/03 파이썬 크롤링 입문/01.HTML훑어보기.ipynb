# %% [markdown]
# 1. HTML 훑어보기
#     - 웹의 기본이되고,
#       원하는 정보가 있는 HTML에 대해 배워보는 시간을 가집니다.

# %% [markdown]
# 목 차
#
# 01. 크롤링에 관하여
#
# 02. HTML - 태그 1
#
# 03. HTML - 태그 2
#
# 04. HTML - 태그 3
#
# 05. HTML - 전역 속성
#
# 06. 맺으며

# %% [markdown]
# 01. 크롤링에 관하여
#
# World Wide Web

# %% [markdown]
# Web Crawler(Web Spider)
#
# 수많은 웹 사이트를 탐험하며 페이지를 수집하는 시스템을
# Web Crawler 또는 Web Spider라고 한다.

# %% [markdown]
# 신문/잡지 스크랩(scrap)
#
# 신문이나 잡지에서 필요한 부분만 잘라 내 노트에 붙였던 것

# %% [markdown]
# Web Scraping
#
# 특정 웹페이지 내용 중 원하는 부분을 내가 원하는 형식으로 만드는 것

# %% [markdown]
# Crawling vs Scraping
#
# 크롤링 기술을 배우기 위한, 스크래핑

# %% [markdown]
# How to scrap?
#
# 웹 페이지 작성 규칙에 따름
#         (HTML)
#
# -> 규칙을 이용해 정리 가능

# %% [markdown]
# 스크래핑을 배우기 전에
#
#             Crawling
# -------------------------------
# scraping        scraping
# --------------------------
#        Web에 대한 사전지식
#
# Web에 대한 지식이 선행 되어야 함

# %% [markdown]
# 웹 페이지의 구조
#
# 엘리스 아카데미 웹 페이지
#     -> 웹 페이지를 구성하는 HTML과 여러 파일

# %% [markdown]
# HTML, CSS, JavaScript
#
# HTML
# - 정보 및 설계도
#
# CSS
# - 디자인 및 스타일링
#
# JS
# - JavaScript
# - 기능과 효과

# %% [markdown]
# 웹 사이트 제작 = 건물 짓기
#
# HTML
# - 건물 설계도
#
# CSS
# - 인테리어 디자인
#
# JavaScript
# - 기능과 효과

# %% [markdown]
# 02. HTML - 태그 1

# %% [markdown]
# HTML이란?
#
# Hyper Text Markup Language
#
# 웹사이트에서 눈에 보이는 정보나 특정 구역을 설정할 때
# 사용하는 언어

# %% [markdown]
# HTML과 요소
#
# HTML
#     - 일련의 요소들로 이루어짐
#
# 요소(Element)
#     - 웹 페이지를 구성하는 것
#     - 콘텐츠(텍스트, 이미지등)를 다른 형식으로
#       보이게 하거나, 특정한 방식으로 동작하게 함

# %% [markdown]
# 요소(Element)
#
# 요소 작성법
#     - <여는 태그 속성 = "속성값"> 텍스트 컨텐츠 </닫는 태그>
#
# 태그
#     - 요소의 특징을 나타냄
#     - "<",태그이름,">"으로 작성
#
# 텍스트 컨텐츠
#     - 요소가 나타낼 텍스트
#
# 속성
#     - 태그가 가진 기본 특징이나 동작을 변경할 수 있게 해줌
#
# 속성값
#     - 해당 속성의 값
#     - 속성에 따라 생략될 수 있음

# %% [markdown]
# 빈 요소
#
# 빈 요소 작성법
#     - <여는 태그 속성 = "속성값">
#
# 특징
#     - 컨텐츠 및 닫는 태그가 없음

# %% [markdown]
# 태그 파헤치기 : <!DOCTYPE>, html

# %%
'''
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>HTML 파헤치기</title>
    </head>
    <body>
        <p>HTML을 파헤쳐보자<p>
    </body>
</html>

'''

# %% [markdown]
# <!DOCTYPE html>
#     - HTML문서임을 선언하는 요소
#     - 문서 맨 윗 줄에 작성하며, html 태그 안에 쓰지 않는다.
#
# <html> ... </html>
#     - HTML 문서의 시작과 끝을 의미
#     - 모든 다른 요소들은 <html>요소 안에 입력

# %% [markdown]
# 태그 파헤치기 : head, body
#
# <head> ... </head> # 1개
#     - 웹 사이트에 대한 설명(=메타데이터)을 적어 넣는 요소
#     - 정확히 한 개의 <title>요소를 포함해야 함
#
# <body> ... </body>
#     - 웹사이트에 표시될 내용을 적어 넣는 요소
#     - 앞으로 배우는 대부분의 요소는 이곳에 작성

# %% [markdown]
# 태그 파헤치기 : meta, title
#
# <meta>
#     - 빈 요소 (닫는 태그 없음)
#     - 해당 HTML 문서의 특징 및 설명을 적는 요소
#     - charset 속성으로 문자 인코딩 선언
#
# <title> ... </title>
#     - 웹 사이트의 제목을 적는 요소

# %%
'''
<!DOCTYPE html>                # HTML5 문서 선언
<html>                         # HTML 문서의 시작
    <head>                     # 문서와 관련된 요약 정보 정리
        <meta charset="utf-8"> # 정보 및 설명
        <title>HTML 파헤치기</title> # 웹 사이트 제목
    </head>
    <body>                     # 웹사이트 내용
        <p>HTML을 파헤쳐보자<p>
    </body>
</html>

'''

# %% [markdown]
# HTML 작성 기초
# HTML은 일련의 요소들로 이루어진다고 배웠는데요, 우리가 직접 요소를 작성해서 웹 페이지의 틀이 잡힌 HTML 문서를 만들어봅시다.
#
# 요소는 다음과 같이 작성할 수 있습니다.
#
# <tag 속성="속성값">텍스트 컨텐츠</tag>
# Copy
# 태그(tag) – 요소의 특징을 나타내며, 여는 태그 <tag> 와 닫는 태그 </tag>로 구성되어 있습니다.
# 속성(attribute) – 태그가 가진 기본 특징이나 동작을 변경할 수 있게 해줍니다.
# 속성값(value) – 속성의 값을 나타내며, 속성에 따라 생략되기도 합니다.
#
# 지시사항
# html5 문서를 선언하는 <!DOCTYPE html>을 입력합니다.
#
# 문서의 시작과 끝을 나타내는 html 요소를 입력합니다.
#
# 웹 사이트의 요약 정보를 담는 head 요소와, 눈에 보이는 정보를 담는 body 요소를 html 요소 안에 입력합니다.
#
# head 요소 안에 문자 코드를 위한 <meta charset="UTF-8"> 를 입력합니다. 그리고 title 요소를 입력하고, 태그 사이에 사이트의 제목을 넣습니다. 제목은 HTML 파헤치기 입니다.
#
# Tips!
# 몇몇 태그를 제외한 대부분의 태그들은 </ > 형태의 닫는 태그를 작성해야 합니다!
#
# 사이트의 제목을 확인하고 싶다면 이 버튼을 눌러서 새 창에서 열어 확인해주세요.
#
# image
#
# 결과 화면
# image

# %%
'''
<!-- 아래에 코드를 완성하고 제출 버튼을 눌러보세요! -->
<!DOCTYPE html>
<html>
    <head>
        <meta charset = "UTF-8">
        <title>HTML 파헤치기</title>
    </head>
    <body>
    
    </body>
</html>
'''

# %% [markdown]
# 03. HTML - 태그 2

# %% [markdown]
# <body>의 영역
#
# <body>
#     - 웹페이지 대부분 영역
#     - 스크래핑으로 정보를 가지오는 부분도 대부분 이부분

# %% [markdown]
# <body>를 꾸며주는 수 많은 요소들

# %%
'''
address article asied footer header h1 h2 h3 h4 h6 h6
main nav section blockquote dd div dl dt 
figcaption figure hr li ol p pre ul a abbr b bdo br 
citecode date dfn em i kbd mark q rb rp rt rtc 
ruby s samp small span string sub sup time u var wbr
area audio img map track video embed iframe boject param
canvas noscript script caption col colgroup table tbody
td th thead tr button datalist fieldset form
input label legend meter optgroup option
output progress select textarea details dialog menu
summary slot template
'''
여러 웹 페이지에서 일반적으로 사용하고, 직관적이어서
이해하기 쉬운 요소 위주로 학습

# %% [markdown]
# 태그 파헤치기 : p
#
# HTML
# <p>Paragraph 1
#    Paragraph 1</p>
# <p>Paragraph 2
#    Paragraph 2</p>
#
# 실행결과
# Paragraph 1 Paragraph 1
#
# Paragraph 2 Paragraph 2
#
# <p> ... </p>
#     - paragraph의 약자로, 문단을 나타냄
#     - 문단 간에는 한줄의 간격 생성

# %% [markdown]
# 태그 파헤치기 : h
#
# HTML
# <h1>Heading 1</h1>
# <h2>Heading 2</h2>
# <h3>Heading 3</h3>
#
# 실행 결과
# Heading 1 # 크기 가장큼
#
# Heading 2 # 1보다 작음
#
# Heading 3 # 2보다 작음
#
# <h?> .... </h?>
#     - heading의 약자로 제목 또는 부제목을 표현
#     - 숫자 값이 클수록 폰트 사이즈가 작음
#     - <h1> 태그는 가장 중요한 제목이므로,
#       하나의 html 문서에서 한 번만 사용되는 것이 옳다.

# %% [markdown]
# 태그 파헤치기 : a
#
# HTML
# <a href="naver.com" target="_blank">네이버</a>
#
# 실행결과
# 네이버 # 하이퍼링크
#
#
# 태그
# <a> ... </a>
#     - anchor의 줄임말로
#       다른 URL로 연결하는 하이퍼 링크를 만드는 태크
#     - 콘텐츠에는 링크의 목적지에 대한 설명이 들어감
#
#
#
# 속성
# href
#     - 하이퍼링크의 목적지 url을 나타내는 속성
#
# target
#     - 해당 링크를 보여줄 위치를 정하는 속성
#     - "_blank" : 새창에서 뜸

# %% [markdown]
# 태그 파헤치기 : img
#
# HTML
# <img src="logo.png" alt="Elice Logo">
#
# 태그
# <img>
#     - 빈 요소
#     - 문서에 이미지를 넣고자 할 때 사용하는 태그
#
# 속성
# src
#     - 보여주고자 하는 이미지의 경로
#     - 필수 속성
#
# alt
#     - 이미지의 대체 텍스트

# %% [markdown]
# <body> 꾸미기
# <a> 태그를 이용해 네이버와 엘리스로 가는 링크 요소를 하나씩 만듭니다. 그 중 엘리스로 가는 링크는 img 요소를 이용해서, 로고를 클릭했을 때 링크로 이동할 수 있게 합니다. 그리고 각 링크에 대한 제목과 부연 설명을 h와 p 요소로 작성합니다.
#
# a 요소는 텍스트 또는 이미지를 클릭했을 때 다른 웹페이지로 이동시키는 기능을 갖고 있습니다.
#
# <a href="https://academy.elice.io/" target="_blank">엘리스</a>
# Copy
# href – 연결할 웹페이지의 URL 주소
# target – 웹페이지를 연결하는 방식
# img 요소는 이미지를 입력할 때 사용합니다.
#
# <img src="elice_logo.png" alt="엘리스 회사 로고" />
# Copy
# src – 입력하고자 하는 이미지 파일
# alt – 이미지를 대신하는 설명
#
# 지시사항
# a 요소를 두 개 만듭니다. 각 요소의 href 속성은 다음과 같습니다.
#
# 네이버: https://naver.com
# 엘리스: https://academy.elice.io
# 각 a 요소의 컨텐츠에는 링크에 대한 설명을 적습니다. 이 때 엘리스와 연결된 a 요소의 컨텐츠에는 img 요소를 적어 넣습니다.
#
# 각 링크에 대한 제목과 부연설명을 a 요소 윗줄에 적습니다. 제목은 <h2> 태그를 이용합니다.
#
# Tips!
# <img> 태그는 닫는 태그가 없습니다.
# 결과 화면
# image

# %%
'''<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <title>엘리스 :: elice</title>
  </head>
  <body>
    <h1>네이버와 엘리스로 연결되는 링크 만들기</h1>
    <!-- 아래 코드를 완성하고 제출 버튼을 눌러보세요! -->
    <h2>네이버로 가는 링크</h2>
    <p>네이버 메인 페이지</p>
    <a href="https://naver.com">네이버</a>
    <h2>엘리스 아카데미 홈페이지 링크</h2>
    <p>엘리스 아카데미 메인페이지</p>
    <a href="https://academy.elice.io">
      <img src="elice_logo.png" alt="엘리스 회사 로고">
    </a>
    
  </body>
</html>
'''

# %% [markdown]
# 04. HTML - 태그 3

# %% [markdown]
# 일반적으로 사용하고, 구역 구획을 나누는 요소

# %% [markdown]
# 태그 파헤치기 : div
#
# HTML
# <div style="background-color: yellow">
#     <p>Background color is yellow.</p>
#     <p>This paragraph is yellow too</p>
# </div>
#
#
# <div> ... </div>
#     - <div> 요소 자체는 아무것도 표현하지 않는 컨테이너
#     - 여러 요소를 하나의 구역으로 묶어 꾸미기 쉽게 해줌
#
#
#     # 위 아래 차이점
#         : 위는 div태그 공간 전부 배경색이 노란색으로
#           아래는 p태그 공간 부분만 배경식이 바뀜
#
# HTML
# <p style ="background-color: yellow">Background color is yellow.</p>
# <p style ="background-color: yellow">This paragraph is yellow too</p>

# %% [markdown]
# 태그 파헤치기 : span
#
# HTML
# <p>
#     Elice is the
#     <span style = "color : red;">best</span>
#     platform of the world.
# </p>
#
# 실행결과
# Elice is the best platform of the world.
# #best부분만 빨간색 글씨
#
# <span> ... </span>
#     - <span>요소도 자체만으론 아무 것도 표현하지 않음
#     - 주로 문장 중간에서 일부분을 꾸며줄 때 사용
#
# #div컨테이너(공간필요) span(공간필요X)

# %% [markdown]
# 태그 파헤치기 : ul
#
# HTML
# <ul> # unorderd list 순서가 없이 표현된 리스트
#     <li>HTML</li>
#     <li>CSS</li>
#     <li>JavaScript</li>
# </ul>
#
# 실행결과
#  ● HTML
#  ● CSS
#  ● JavaScript
#
# <ul> ... </ul>
#     - 비정렬 목록
#     - 순서가 없는 리스트를 표현할 때 사용
#     - 불릿으로 표현됨
#
# <li> ... </li>
#     - 목록의 항목
#     - 정렬 태그인<ol>,<ul>안에서 사용해야함

# %% [markdown]
# 태그 파헤치기 : ol
#
# HTML
# <ol> # ordered list
#     <li>HTML</li>
#     <li>CSS</li>
#     <li>JavaScript</li>
# </ol>
#
# 실행결과
# 1. HTML
# 2. CSS
# 3. JavaScript
#
# <ol> ... </ol>
#     - 정렬 목록
#     - 순서가 있는 리스트를 표현할 때 사용
#     - 숫자 또는 알파벳의 오름차순으로 표현됨

# %% [markdown]
# 구역 설정 및 여러 요소 한꺼번에 꾸미기
# 이미 적혀있는 p 요소 네 개를 div 요소를 이용하여 구역을 나누고, 한꺼번에 꾸며봅니다.
#
# 네 줄 모두 글씨 색을 파란 색으로 바꾸고, 셋째 줄과 넷째 줄은 글씨 크기를 2배로 변경 해봅시다.
#
# 마지막으로 넷째 줄의 ‘넷째’ 단어만 span 요소를 이용해서 글씨 색을 빨간 색으로 바꿔봅시다.
#
# div 요소는 여러 요소들을 하나의 공간 안에 감싸고, 한꺼번에 style 을 입힐 수 있게 해줍니다.
#
# <div style="...">여러 요소들</div>
# Copy
#
# 지시사항
# 첫째 줄부터 넷째 줄까지 모두 포함하도록 <div>, </div>를 작성합니다.
#
# 여는태그(<div>)에 style 속성을 추가합니다. 속성값은 글씨 색깔을 바꿔주도록 color: blue를 적습니다.
#
# 셋째 줄과 넷째 줄을 포함하도록 <div>, </div>를 작성합니다.
#
# 이 요소에도 style 속성을 추가합니다. 속성값은 글씨 크기를 2배로 바꿔주도록 font-size: 2em 을 적습니다.
#
# ‘넷째’ 라는 단어만 <span>과 </span>으로 감싸줍니다.
#
# 그리고 여는 태그(<span>)에 style 속성을 추가합니다. 속성값은 color: red입니다.
#
# Tips!
# style 속성에 여러 속성값을 적용시키고 싶다면 ; 를 이용해서 구분합니다. (e.g. style="font-size: 16px; color: red")
#
# 지시사항 5번의 예시 코드입니다.
#
# <p><span>넷째</span>줄</p>
# Copy
# 결과 화면
# image

# %%
'''
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <title>엘리스 :: elice</title>
  </head>
  <body>
    <!-- 아래 코드를 완성하고 제출 버튼을 눌러보세요! -->
    <div style="color : blue;">
        <p>첫째 줄</p>
        <p>둘째 줄</p>
        <div style="font-size : 2em;">
            <p>셋째 줄</p>
            <p><span style="color : red;">넷째</span>줄</p>
        </div>
    </div>
  </body>
</html>

'''

# %% [markdown]
# 리스트 적용하기
# 다음은 파이썬 웹 크롤링 트랙을 공부하는 순서를 누군가 적어 놓은 페이지입니다.
#
# image
#
# 그런데 이 학생은 리스트를 아직 배우지 않았는지, p 요소를 이용해서 리스트를 작성했군요! (error.html 참고)
#
# 우리가 리스트를 이용해서 똑같은 내용을 똑똑하게 작성해봅시다.
#
# ol: 순서가 있는 리스트 (ordered list)
# ul: 순서가 없는 리스트 (unordered list)
# li: 리스트의 항목 (list item)
# ul과 ol은 혼합해서 사용할 수 있습니다.
#
# <ol>
#   <li>텍스트</li>
#   <li>
#     텍스트
#     <ul>
#       <li>텍스트</li>
#       <li>텍스트</li>
#     </ul>
#   </li>
# </ol>
# Copy
#
# 지시사항
# 번호가 붙은 리스트를 만들기 위해 ol 요소를 만듭니다.
# ol 요소 안에 li 요소 3개를 만들고, 각 과목의 이름을 적습니다.
# 웹 크롤링 과목에선 두 가지 주제를 배웁니다. 이를 표현하기 위해 두 번째 li 요소 안에 ul 요소를 새로 추가합니다.
# ul 요소 안에 li 요소 2개를 만들고, 각 주제의 이름을 적습니다.
# 결과 화면
# image

# %%
# error.html
'''
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <title>엘리스 :: elice</title>
  </head>
  <body>
    <p>1. 파이썬</p>
    <p>2. 웹 크롤링</p>
    <p>◦ HTML</p>
    <p>◦ Selenium</p>
    <p>3. 크롤링 프로젝트</p>
  </body>
</html>
'''

#index.html
'''
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <title>엘리스 :: elice</title>
  </head>
  <body>
    <!-- ol, ul, li 요소를 이용하여 새로 만들어 보세요! -->
    <ol>
        <li>파이썬</li>
        <li>웹 크롤링
            <ul>
                <li>HTML</li>
                <li>Selenium</li>
            </ul>
        </li>
        <li>크롤링 프로젝트</li>
    </ol>
  </body>
</html>

'''

# %% [markdown]
# 05. HTML - 전역 속성

# %% [markdown]
# 태그와 속성
#
# 예시
# <a href="naver.com" target="_blank">네이버</a>
# <img src="logo.png" alt="Elice Logo">
#
# href,target 속성은 <a> 태그,
# src, alt 속성은 <img>태그와 짝을 이룸

# %% [markdown]
# 전역 속성(global attributes)
#
# 모든 요소가 공통으로 사용할 수 있는 속성

# %% [markdown]
# 속성 파헤치기 : style
#
# HTML
# <div style="background-color : yellow;">
#
#     <p style="color : red;">Red</p>
#     <p style="color : red;
#               font-size : 24px;">Big Red</p>
#
# </div>
#
# 실행결과
# Red
#
# Big Red
# #div태그(컨테이너)공간 배경은 노란색
# #첫 p태그는 글자만 빨간색
# #두 번째 p태그는 글자 빨간색 font-size 24픽셀
#
# style
#     - 요소에 CSS 스타일을 적용
#     - 테스트 용도로 적합
#     # 테스트 말고 스타일을 입히고 싶을 때 class 속성 사용

# %% [markdown]
# 속성 파헤치기 : class
#
# CSS
# .warning { background-color : yellow; }
# .red { color : red; }
# .big { font-size : 24px; }
#
# HTML
# <div class="warning">
#     <p class="red">Red</p>
#     <p calss="big red">Big Red</p>
# </div>
#
# 실행결과
# Red
#
# Big Red
# #div태그(컨테이너)공간 배경은 노란색
# #첫 p태그는 글자만 빨간색
# #두 번째 p태그는 글자 빨간색 font-size 24픽셀
#
# class
#     - 특정 요소에 스타일 또는 스크립트를 적용하기 위해 사용
#     - 각 요소는 여러 class를 가질 수 있음

# %% [markdown]
# 속성 파헤치기 : id
#
# CSS
# .warning { background-color : yellow; } #class
# .red { color : red; } #class
# .big { font-size : 24px; } #class
# #black-p {color : black; } #id
#
# HTML
# <div class="warning">
#     <p id="black-p">Red</p>
#     <p class="big red">Big Red</p>
# </div>
#
# 실행결과
# Red
#
# Big Red
# #div태그(컨테이너) 클래스 속성 적용 노란색 배경
# #첫 p태그 id속성 적용 글자색 검은색
# #두 번째 p태그 클래스 big, red 적용 빨간색 글자 폰트사이즈 24px
#
# id
#     - 특정 요소에 스타일 또는 스크립트를 적용하기 위해 사용
#     - 각 요소는 하나의 id만 가질 수 있음
#
# class id <- scraping에 사용됨

# %% [markdown]
# 속성 파헤치기 : hidden
#
# CSS
# .warning { background-color : yellow; } #class
# .red { color : red; } #class
# .big { font-size : 24px; } #class
# #black-p {color : black; } #id
#
# HTML
# <div class="warning">
#     <p hidden>Red</p>
#     <p class="big red">Big Red</p>
# </div>
#
# 실행결과
# Big Red
# #div태그(컨테이너)공간 class warning적용
# #두 번째 p태그 class big, red 적용
# #첫 번째 p태그 hidden
#
# hidden
#     - 해당 요소를 보이지 않게 함
#     - hidden="hidden"대신 간략히 hidden만 적을 수 있음

# %% [markdown]
# 속성 파헤치기 : title
#
# HTML
# <img src="html5.png" title="HTML5">
# <p>html 로고</p>
#
#
# 실행결과
# 로고이미지
# html 로고
# #로고이미지에 툴팁생성되어 마우스를 가져다 되면 툴팁이 나옴
#
#
# title
#     - 요소와 관련된 툴팁 제공

# %% [markdown]
# 전역 속성 적용하기
# 이번 웹 페이지는 엘리스 로고와 그에 대한 설명이 적혀있습니다. 하지만 글씨와 이미지만 있어서 너무 딱딱한 것 같습니다.
#
# 여기에 여러 style을 입혀 웹 페이지를 꾸며보도록 합니다. 다음은 미리 만들어놓은 style 내용입니다.
#
# .frame {
#   background-color: yellow;
#   border: 5px outset red;
#   padding: 5px;
# } /* 배경 노랑색, 테두리 5px의 빨강색, 여백 5px */
#
# .center {
#   text-align: center;
# } /* 가운데 정렬 */
# Copy
# 태그에 class 속성을 추가하는 방법입니다.
#
# <tag class="className">...</tag>
# Copy
#
# 지시사항
# h1 요소를 가운데 정렬하기 위해 class 속성을 추가하고, 속성값으로 center 를 적습니다.
#
# 액자같은 배경을 적용하기 위해 div 요소에 class 속성을 추가하고, 속성값으로 frame 을 적습니다.
#
# 또 해당 공간 내의 요소들을 가운데 정렬하기 위해 class 속성에 center 를 추가합니다.
#
# img 요소에 툴팁을 추가하기 위해 title 속성을 추가합니다. 속성값은 엘리스 로고 입니다.
#
# 툴팁이 추가 돼서 이제 엘리스 로고라는 본문은 필요 없어보입니다. 해당 요소에 hidden 속성을 추가해서 웹 페이지상에서 보이지 않게 해줍니다.
#
# Tips!
# class 속성은 여러 개의 속성값을 적을 수 있습니다. 속성값은 공백()으로 구분합니다.
# <tag class="class1 class2 class3 ...">
# Copy
# 결과 화면
# image

# %%
'''
<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <style>
      .frame {
        background-color: yellow;
        border: 5px outset red;
        padding: 5px;
      }

      .center {
        text-align: center;
      }
    </style>
    <title>엘리스 :: elice</title>
  </head>
  <body>
    <!-- 아래 코드를 완성하고 제출 버튼을 눌러보세요! -->
    <h1 class="center">엘리스</h1>
    <div class="frame center">
      <img src="elice_logo.png" alt="elice logo" title="엘리스 로고" />
      <p hidden="hidden">엘리스 로고</p>
    </div>
  </body>
</html>

'''

# %% [markdown]
# 06. 맺으며

# %% [markdown]
# 태그 1, 2
#   요소명                 내 용
# !DOCTYPE     html 문서임을 선언하는 요소
#   html       html 문서의 최상단 요소(root요소)
#   head       문서의 요약 정보가 담김
#   body       웹 페이지에 표시될 내용이 담김
#   meta       문서를 설명하는 정보
#   title      웹 페이지의 제목
#
#   p          문단
#   h1~h6      각 구획의 제목
#   a          하이퍼링크
#   img        이미지

# %% [markdown]
# 태그3, 전역속성
#
#   요소명                 내 용
#    div           여러 요소를 한 구역에 묶음
#    span          요소 중간에서 꾸며줌
#    li            리스트의 항목(ul,ol 안에서 사용)
#    ul            순서 없는 리스트(비정렬 목록)
#    ol            순서 있는 리스트(정렬 목록)
#
#
#   속성명                 내 용
#   style         CSS문법 적용, 테스트 용도 적합
#   class         스타일, 스크립트를 특정 요소에 적용 : 다중 가능
#     id          스타일, 스크립트를 특정 요소에 적용 : 한개만
#   hidden        요소가 웹에서 보이지 않게 함
#   title               툴팁 제공

# %% [markdown]
# 다음 수업 예고
#
# python         Selenium
#
#
# 네이버 뉴스 헤드라인   ->      헤드라인 구역의 html
#
# -> Selenium을 통해 스크래핑 해옴(data)

# %% [markdown]
# HTML 훑어보기
# 파이썬 크롤링에 입문하신 여러분을 환영합니다 🤗
# 이번 장에서는 크롤링 기술을 배우기 위한 첫 단계로, 웹을 설계하기 위한 HTML의 기본 개념을 학습했어요!
# 처음 접하는 내용이 많았을텐데, 우리 함께 복습하러 가요~
#
#
#
# 1. 크롤링에 관하여
# Web Crawler: 수많은 웹사이트를 탐험하며 페이지를 수집하는 시스템으로, Web Spider라고도 합니다.
# Web Scrapping: 특정 웹 페이지 내용 중 원하는 부분을 내가 원하는 형식으로 만드는 것을 말합니다. 웹 페이지 작성 규칙을 따르며 정리할 수 있습니다.
# 크롤링 기술을 배우기 위한 발판이 스크래핑이고, 스크래핑을 배우기 전에 웹(Web)에 대한 지식이 선행되어야 합니다. 따라서 이번 장에서는 웹의 설계도인 HTML에 대해 학습했습니다.
#
#
#
# 2. HTML이란?
# HTML이란 Hyper Text Markup Language의 약자로, 웹사이트에서 눈에 보이는 정보나 특정 구역을 설정할 때 사용하는 언어입니다.
#
# Point I
# HTML의 구성 요소
#
#
# <여는 태그 속성 = "속성값"> 텍스트 컨텐츠 </닫는 태그>
# 태그: 요소의 특징을 나타냄
# 텍스트 컨텐츠: 요소가 나타낼 텍스트
# 속성: 태그가 가진 기본 특징이나 동작을 변경할 수 있게 해줌
# 속성값: 해당 속성의 값을 나타내며, 속성에 따라 생략될 수 있음
# Point II
# 빈 요소: 컨텐츠 및 닫는 태그가 없는 요소
#
# <여는 태그 속성 = "속성값">
#
#
# 3. HTML 태그
# Point I
# HTML 기본 태그
#
# <!DOCTYPE html> <!-- HTML5 문서 선언-->
# <html> <!-- HTML 문서의 시작과 끝 -->
#     <head> <!-- 문서와 관련된 요약 정보 -->
#         <meta charset="UTF-8"> <!-- 정보 및 설명 -->
#         <title>HTML 파헤치기</title> <!-- 웹사이트 제목 -->
#     </head>
#     <body> <!-- 웹사이트 내용 -->
#         <p> HTML을 파헤쳐보자!</p>
#     </body>
# </html>
# <!DOCTYPE html>: HTML 문서임을 선언하는 요소로, 문서 맨 윗줄에 작성하며 html 태그 안에 쓰지 않음
# <html>...</html>: HTML 문서의 시작과 끝을 나타내는 요소로, 모든 다른 요소들은 <html> 요소 안에 입력
# <meta>: HTML 문서의 특징 및 설명을 적는 빈 요소로, charset 속성으로 문자 인코딩을 선언
# <title>...</title>: 웹사이트의 제목을 적는 요소
# <head>...</head>: 웹사이트에 대한 설명을 적어 넣는 요소로, 정확히 한 개의 <title> 요소를 포함해야 함
# <body>...</body>: 웹사이트에 표시될 내용을 적어 넣는 요소
# Point II
# <body>를 꾸며주는 태그
#
# <p> 태그: paragraph의 약자로 문단을 나타내며 문단 간에는 한 줄의 간격을 생성
#
#
# <h#> 태그: heading의 약자로 제목 또는 부제목을 표현
#
#
# 숫자가 클수록 폰트 사이즈가 작음
# <h1> 태그는 가장 중요한 제목이므로, 하나의 html 문서에서 한 번만 사용
# <a> 태그: anchor의 약자로 다른 URL로 연결하는 하이퍼링크를 만드는 태그
#
#
# 콘텐츠에는 링크의 목적지에 대한 설명이 들어감
# href: 하이퍼링크의 목적지 URL을 나타내는 속성
# target: 해당 링크를 보여줄 위치를 정하는 속성
# <img> 태그: 문서에 이미지를 넣고자 할 때 사용하는 태그
#
#
# src: 보여주고자 하는 이미지의 경로 (필수 속성)
# alt: 이미지의 대체 텍스트
# <div> 태그: 여러 요소를 하나의 구역으로 묶어주는 태그
#
#
# <div> 요소 자체는 아무것도 표현하지 않는 컨테이너
# <span> 태그: 주로 문장 중간에서 일부분을 꾸며줄 때 사용하는 태그
#
#
# <span> 요소 자체는 아무것도 표현하지 않음
# <ul> 태그: unordered list의 약자로 순서가 없는 리스트를 표현할 때 사용
#
#
# 불릿으로 표현됨
# <li>: 목록의 항목으로 정렬 태그 안에서 사용해야 함
# <ol> 태그: ordered list의 약자로 순서가 있는 리스트를 표현할 때 사용
#
#
# 숫자 또는 알파벳의 오름차순으로 표현됨
#
#
# 3. HTML 전역 속성
# 전역 속성은 모든 요소가 공통으로 사용할 수 있는 속성을 말합니다.
#
# Point I
# style: 요소에 CSS 스타일 적용
#
# <div style="background-color: yellow;">
#     <p style="color: red;">Red</p>
# </div>
# Point II
# class: 특정 요소에 스타일 또는 스크립트를 적용하기 위해 사용하며, 각 요소는 여러 class를 가질 수 있음
#
# .warning { background-color: yellow; }
# .red { color: red; }
# .big { font-size: 24px; }
#
# <div class="warning">
#     <p class="red">Red</p>
#     <p class="big red">Big Red</p> <!-- big과 red class 둘 다 가짐 -->
#  </div>
# Point III
# id: 특정 요소에 스타일 또는 스크립트를 적용하기 위해 사용하며, 각 요소는 하나의 id만 가질 수 있음
#
# .warning { background-color: yellow; }
# .red { color: red; }
# .big { font-size: 24px; }
# #black-p [color:black; }
#
# <div class="warning">
#     <p id="black-p">Red</p>
#     <p class="big red">Big Red</p>
# </div>
# Point IV
# hidden: 해당 요소를 보이지 않게 함
#
# <div class="warning">
#     <p hidden">Red</p> <!-- 보이지 않음 -->
#     <p class="big red">Big Red</p>
# </div>
# hidden="hidden" 대신 간략히 hidden만 적을 수 있음
# Point V
# title: 요소와 관련된 툴팁 제공
#
# <img src="html5.png" title="HTML5">
# <p>html 로고</p>
